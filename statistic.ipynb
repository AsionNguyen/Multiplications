# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "out_512_500.txt"

# %%
data=pd.read_csv(file, sep=',')

# %%
data
# Out:
#      Karatsuba        SS  Optimized
# 0     0.001446  0.001308   0.000539
# 1     0.001839  0.000592   0.000108
# 2     0.001900  0.000990   0.000072
# 3     0.001467  0.000952   0.000183
# 4     0.001707  0.000920   0.000062
# ..         ...       ...        ...
# 495   0.001409  0.000907   0.000067
# 496   0.001408  0.000757   0.000056
# 497   0.001410  0.000884   0.000067
# 498   0.001441  0.000986   0.000067
# 499   0.001458  0.000003   0.000003
#
# [500 rows x 3 columns]

# %%
X = data["Karatsuba"]
Y = data["SS"]
Z = data["Optimized"]

# %%
plt.plot(X, color='r', label="Karatsuba")
plt.plot(Y, color='b', label="SS")
plt.plot(Z, color='g', label="Optimized")
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("samplers")
plt.ylabel("seconds")
plt.title("Flint Multiplication comparaison")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(X, 'ro', markersize=1, label="Karatsuba")
plt.plot(Y, 'bo', markersize=1, label="SS")
plt.plot(Z, 'go', markersize=1, label="Optimized")
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("samplers")
plt.ylabel("seconds")
plt.title("Flint Multiplication comparaison")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()
